# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND                  CREATED             STATUS                         PORTS               NAMES
# fff0e1852317        busybox              "sh ./docker_bash.sh"    15 minutes ago      Exited (2) 15 minutes ago                          peaceful_cartwright
# 3352369d833e        busybox              "sh docker_bash.sh"      15 minutes ago      Exited (2) 15 minutes ago                          adoring_morse
# 25a4303e4e96        busybox              "sh docker_bash.sh"      16 minutes ago      Exited (2) 16 minutes ago                          brave_shaw
# 8342a8069d81        busybox              "sh ./docker_bash.sh"    16 minutes ago      Exited (2) 16 minutes ago                          frosty_austin
# dddbdf2bdefc        busybox              "sh"                     24 minutes ago      Up 24 minutes                                      nervous_darwin
# ...

# %% [markdown]
# #Docker training Notebook:

# %% [markdown]
# Step 0:test the colab notebook with the remote runtime

# %%
a=[1]
print (a)
# Out:
# [1]

# %% [markdown]
# Step 1: Create a Colab NoteBook with local access to Jupiter Notebook (JNB)
#   need to install the JNB and connect it to this colab notebook
#
#   https://research.google.com/colaboratory/local-runtimes.html
#
# hmmm,  Question here is still on what is the advantage of this kinda of notebook to a regular JNB?
#
# > Indented block
# One thing I can think of is the access to the Remote Kernel
# and it seems that it is saving the notebook on the GDrive direcly.
# the text editing seems nicer too, but I don't work with notebooks mucch to know
#       (Anything else?). oh well, the access to remote host is not particulary usefull here anyway.
#       for the docker test stuff I need to run commands on the OS and it has to
#       be local.
#
# So let see how to run shell commands in JNB

# %% [markdown]
# How to run shell commands in the JNB
#
#
# > In Jupyter Notebook you can execute Terminal commands in the notebook cells by prepending an exclamation point/bang(!) to the beginning of the command.

# %%
# %cd media/hossein/
# !ls
# Out:
# /media/hossein
#  A0B4184DB4182874   HDD  'My Passport22'

# %% [markdown]
# step 2 install docker and do the tutorials there:
#
# https://docs.docker.com/get-docker/
#
# https://docs.docker.com/get-started/part2/

# %%
# !docker images
# Out:
# REPOSITORY          TAG                 IMAGE ID            CREATED             SIZE
# busybox             latest              edabd795951a        39 hours ago        1.22MB
# bulletinboard       1.0                 db265a6fa6b3        5 weeks ago         183MB
# node                current-slim        a8c8ef7c9050        5 weeks ago         167MB
# hello-world         latest              bf756fb1ae65        8 months ago        13.3kB

# %%
# !docker run hello-world:latest
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# Some tutorial stuff  from the https://docker-curriculum.com/

# %%
# !docker run busybox

# %% [markdown]
#  When you call run, the Docker client finds the image (busybox in this case), loads up the container and then runs a command in that container.  we didn't provide a command, so the container booted up, ran an empty command and then exited.

# %%
# !docker run busybox echo "hello from busybox"
# Out:
# hello from busybox

# %% [markdown]
# **Listing the currently running containers and then all containers**

# %%
# !docker ps
# Out:
# CONTAINER ID        IMAGE               COMMAND             CREATED             STATUS              PORTS               NAMES

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND                  CREATED             STATUS                      PORTS               NAMES
# 4bbebc4a61b3        busybox              "echo 'hello from bu…"   59 seconds ago      Exited (0) 59 seconds ago                       friendly_kalam
# fc716460cbd3        busybox              "sh"                     3 minutes ago       Exited (0) 3 minutes ago                        angry_hermann
# ab321a8b3b42        hello-world:latest   "/hello"                 50 minutes ago      Exited (0) 50 minutes ago                       blissful_kilby
# ff53f58c645e        hello-world          "/hello"                 4 weeks ago         Exited (0) 4 weeks ago                          crazy_herschel
# 234bb1d64704        hello-world          "/hello"                 5 weeks ago         Exited (0) 5 weeks ago                          stoic_heisenberg

# %% [markdown]
# **Q:** Is there a way to run more than just one command in a container?

# %%
# !docker run -it busybox sh
# Out:
# / # ^C
# / #
# / #

# %% [markdown]
# oh shoot looks like we can't go into docker container here! ok lets see if there is a work around!

# %%
# %cd HDD/gdrive/SkillsLearningTraining/
# !ls
# Out:
# 'Copy of 05.01-What-Is-Machine-Learning.ipynb'
# 'Copy of Index.ipynb'
#  docker_training.ipynb
# 'Python Data Science Handbook.txt'

# %%
# !docker run -it busybox  sh ./docker_bash.sh
# Out:
# sh: can't open './docker_bash.sh': No such file or directory

# %% [markdown]
# well this does not work; obviously my try and error did not work and  I am doing something wrong, we will find out later, but for now, we would try just presume this in the terminal.

# %% [markdown]
# Running the run command with the -it flags attaches us to an interactive tty in the container.
# docker run command,  would most likely be the command you'll use most often.

# %% [markdown]
# We saw above that we can still see remnants of the container even after we've exited by running docker ps -a.  you'll run docker run multiple times and leaving stray containers will eat up disk space. Hence, as a rule of thumb, I clean up containers once I'm done with them.

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND                  CREATED             STATUS                         PORTS               NAMES
# bca5749ee005        busybox              "sh"                     9 minutes ago       Up 8 minutes                                       mystifying_wilson
# 9afe6c08c44a        busybox              "sh ./docker_bash.sh"    12 minutes ago      Exited (2) 12 minutes ago                          determined_wright
# a22c95994508        busybox              "./docker_bash.sh"       13 minutes ago      Created                                            eloquent_curie
# fff0e1852317        busybox              "sh ./docker_bash.sh"    13 minutes ago      Exited (2) 13 minutes ago                          peaceful_cartwright
# 3352369d833e        busybox              "sh docker_bash.sh"      14 minutes ago      Exited (2) 14 minutes ago                          adoring_morse
# ...

# %%
# !docker rm bca5749ee005 9afe6c08c44a  a22c95994508
# Out:
# 9afe6c08c44a
# a22c95994508
# Error response from daemon: You cannot remove a running container bca5749ee005fcd58a7039661121ec76d04162dee8d2ab682f6ceee7658c6e4f. Stop the container before attempting removal or force remove

# %%
# !docker rm bca5749ee005 9afe6c08c44a  a22c95994508
# Out:
# bca5749ee005
# Error: No such container: 9afe6c08c44a
# Error: No such container: a22c95994508

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND                  CREATED             STATUS                         PORTS               NAMES
# fff0e1852317        busybox              "sh ./docker_bash.sh"    15 minutes ago      Exited (2) 15 minutes ago                          peaceful_cartwright
# 3352369d833e        busybox              "sh docker_bash.sh"      15 minutes ago      Exited (2) 15 minutes ago                          adoring_morse
# 25a4303e4e96        busybox              "sh docker_bash.sh"      16 minutes ago      Exited (2) 16 minutes ago                          brave_shaw
# 8342a8069d81        busybox              "sh ./docker_bash.sh"    16 minutes ago      Exited (2) 16 minutes ago                          frosty_austin
# dddbdf2bdefc        busybox              "sh"                     24 minutes ago      Up 24 minutes                                      nervous_darwin
# ...

# %%
# !docker rm fff0e1852317 3352369d833e  25a4303e4e96 8342a8069d81  dddbdf2bdefc
# Out:
# fff0e1852317
# 3352369d833e
# 25a4303e4e96
# 8342a8069d81
# Error response from daemon: You cannot remove a running container dddbdf2bdefc3de603f6c94ce8820537315f15fbba10ca004c053dbea7690694. Stop the container before attempting removal or force remove

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND                  CREATED             STATUS                         PORTS               NAMES
# dddbdf2bdefc        busybox              "sh"                     27 minutes ago      Up 27 minutes                                      nervous_darwin
# 7aa0b6631d1d        busybox              "sh , ls"                27 minutes ago      Exited (2) 27 minutes ago                          peaceful_hermann
# cb4337aa2029        busybox              "sh , ls"                27 minutes ago      Exited (2) 27 minutes ago                          busy_golick
# 92bc1ef7c153        busybox              "sh"                     27 minutes ago      Up 27 minutes                                      brave_beaver
# 8dfe2153fbc3        busybox              "sh"                     28 minutes ago      Up 28 minutes                                      zealous_grothendieck
# ...

# %%
# !docker rm 7aa0b6631d1d  cb4337aa2029 44afaa4e50d7 4bbebc4a61b3  fc716460cbd3
# Out:
# 7aa0b6631d1d
# cb4337aa2029
# 44afaa4e50d7
# 4bbebc4a61b3
# fc716460cbd3

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND             CREATED             STATUS                   PORTS               NAMES
# dddbdf2bdefc        busybox              "sh"                29 minutes ago      Up 29 minutes                                nervous_darwin
# 92bc1ef7c153        busybox              "sh"                29 minutes ago      Up 29 minutes                                brave_beaver
# 8dfe2153fbc3        busybox              "sh"                30 minutes ago      Up 30 minutes                                zealous_grothendieck
# 5cbfefd2b81f        busybox              "sh"                59 minutes ago      Up 59 minutes                                dazzling_hugle
# 1c45cf2e260d        busybox              "sh"                About an hour ago   Up About an hour                             elated_cray
# af1e11658c1e        busybox              "sh"                About an hour ago   Up About an hour                             trusting_ride
# ...

# %% [markdown]
# hmmm, so the containers that I created with JNB above, are still running, so how to delete a container that is running?

# %%
# !docker kill 1c45cf2e260d
# Out:
# 1c45cf2e260d

# %%
# !docker kill af1e11658c1e 5cbfefd2b81f 8dfe2153fbc3 92bc1ef7c153 dddbdf2bdefc
# !docker ps -a
# Out:
# af1e11658c1e
# 5cbfefd2b81f
# 8dfe2153fbc3
# 92bc1ef7c153
# dddbdf2bdefc
# CONTAINER ID        IMAGE                COMMAND             CREATED             STATUS                        PORTS               NAMES
# dddbdf2bdefc        busybox              "sh"                34 minutes ago      Exited (137) 1 second ago                         nervous_darwin
# 92bc1ef7c153        busybox              "sh"                35 minutes ago      Exited (137) 1 second ago                         brave_beaver
# 8dfe2153fbc3        busybox              "sh"                35 minutes ago      Exited (137) 1 second ago                         zealous_grothendieck
# 5cbfefd2b81f        busybox              "sh"                About an hour ago   Exited (137) 1 second ago                         dazzling_hugle
# 1c45cf2e260d        busybox              "sh"                About an hour ago   Exited (137) 59 seconds ago                       elated_cray
# ...

# %%
# !docker rm af1e11658c1e 5cbfefd2b81f 8dfe2153fbc3 92bc1ef7c153 dddbdf2bdefc
# Out:
# af1e11658c1e
# 5cbfefd2b81f
# 8dfe2153fbc3
# 92bc1ef7c153
# dddbdf2bdefc

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE                COMMAND             CREATED             STATUS                            PORTS               NAMES
# 1c45cf2e260d        busybox              "sh"                About an hour ago   Exited (137) About a minute ago                       elated_cray
# ab321a8b3b42        hello-world:latest   "/hello"            2 hours ago         Exited (0) 2 hours ago                                blissful_kilby
# ff53f58c645e        hello-world          "/hello"            4 weeks ago         Exited (0) 4 weeks ago                                crazy_herschel
# 234bb1d64704        hello-world          "/hello"            5 weeks ago         Exited (0) 5 weeks ago                                stoic_heisenberg
